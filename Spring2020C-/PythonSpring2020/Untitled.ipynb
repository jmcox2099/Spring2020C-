# %%
import pandas as pd
import sqlite3
import os


db = sqlite3.connect("SoccerStats.db")

df1 = pd.read_csv("SoccerGameResults.csv")

df1.to_sql("stage_stats_import", db, if_exists="replace")

def run_query(query):
    return pd.read_sql_query(query,db)

os.getcwd()
# Out:
# 'C:\\Users\\G.I.Jesus\\Desktop\\Source\\PythonSpring2020'

# %%
df1
# Out:
#                 GameDate              TeamName HomeOrAway  Goals  \
# 0     8/26/2015 05:30 PM          Chicago Fire       Home    3.0
# 1     8/26/2015 05:30 PM    New York Red Bulls       Away    2.0
# 2     8/26/2015 06:00 PM       Colorado Rapids       Home    2.0
# 3     8/26/2015 06:00 PM        Houston Dynamo       Away    1.0
# 4     8/28/2015 08:00 PM  San Jose Earthquakes       Home    1.0
# ..                   ...                   ...        ...    ...
# 175  10/25/2015 04:00 PM        Real Salt Lake       Away    1.0
# 176  10/25/2015 04:00 PM    Los Angeles Galaxy       Away    1.0
# 177  10/25/2015 04:00 PM        Houston Dynamo       Away    0.0
# 178                  NaN                   NaN        NaN    NaN
# 179                  NaN                   NaN        NaN    NaN
#
#      GoalAttempts  ShotsOnGoal  ShotsOffGoal  PosessionPercent
# 0            16.0          5.0          11.0             48.68
# ...

# %%
query = """
SELECT *
FROM sqlite_master
ORDER BY name;
"""
run_query(query)
# Out:
#     type                         name            tbl_name  rootpage  \
# 0  index  ix_stage_stats_import_index  stage_stats_import         9
# 1  index               ix_stats_index               stats         3
# 2  table           stage_stats_import  stage_stats_import         7
# 3  table                        stats               stats         2
#
#                                                  sql
# 0  CREATE INDEX "ix_stage_stats_import_index"ON "...
# 1  CREATE INDEX "ix_stats_index"ON "stats" ("index")
# 2  CREATE TABLE "stage_stats_import" (\n"index" I...
# 3  CREATE TABLE "stats" (\n"index" INTEGER,\n  "G...

# %%
query = """
SELECT *
FROM stage_stats_import;
"""

run_query(query)
# Out:
#      index             GameDate              TeamName HomeOrAway  Goals  \
# 0        0   8/26/2015 05:30 PM          Chicago Fire       Home    3.0
# 1        1   8/26/2015 05:30 PM    New York Red Bulls       Away    2.0
# 2        2   8/26/2015 06:00 PM       Colorado Rapids       Home    2.0
# 3        3   8/26/2015 06:00 PM        Houston Dynamo       Away    1.0
# 4        4   8/28/2015 08:00 PM  San Jose Earthquakes       Home    1.0
# ..     ...                  ...                   ...        ...    ...
# 175    175  10/25/2015 04:00 PM        Real Salt Lake       Away    1.0
# 176    176  10/25/2015 04:00 PM    Los Angeles Galaxy       Away    1.0
# 177    177  10/25/2015 04:00 PM        Houston Dynamo       Away    0.0
# 178    178                 None                  None       None    NaN
# 179    179                 None                  None       None    NaN
#
#      GoalAttempts  ShotsOnGoal  ShotsOffGoal  PosessionPercent
# ...

# %%
query_format_columns = """
SELECT
df.drop
,df.drop(axis=1)

from_stage_stats_import
"""

run_query(query_format_columns)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1594             else:
# -> 1595                 cur.execute(*args)
#    1596             return cur
#
# OperationalError: near "drop": syntax error
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-7-6c2b5e178d55> in <module>
#       7 """
#       8
# ----> 9 run_query(query_format_columns)
#
# <ipython-input-1-a37dc19261e3> in run_query(query)
#      11
#      12 def run_query(query):
# ---> 13     return pd.read_sql_query(query,db)
#      14
#      15 os.getcwd()
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
# ...
